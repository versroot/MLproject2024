# %%
import numpy as np
from sklearn import preprocessing, decomposition

train_data = np.load('MLProject2024/fashion_train.npy') 
test_data = np.load('MLProject2024/fashion_test.npy')
train_images = train_data[:, :-1]
test_images = test_data[:, :-1]
train_labels = train_data[:, -1].astype(int)
test_labels = test_data[:, -1].astype(int)

# Apply PCA and combine features with labels
pca = decomposition.PCA(16)
pca_train = pca.fit_transform(train_images)
pca_test = pca.transform(test_images)
train_data_pca = np.hstack((pca_train, train_labels.reshape(-1, 1)))

# %%
def gini_group(dataset):
    '''Calculates the Gini impurity for a group of data. Same as befor but for any n'''
    labels = dataset[:, -1].astype(int)
    counts = np.bincount(labels)
    n = counts.sum()
    if n == 0:
        return 0
    probs = counts / n
    gini = 1 - np.sum(probs ** 2)
    return gini

def gini_split(left, right):
    '''Calculates the Gini impurity for a split.'''
    n_left = len(left)
    n_right = len(right)
    n_total = n_left + n_right
    if n_total == 0:
        return 0
    gini = (n_left / n_total) * gini_group(left) + (n_right / n_total) * gini_group(right)
    return gini

def split(dataset, column, value):
    '''Splits the dataset based on the given feature and value.'''
    left = dataset[dataset[:, column] < value] 
    right = dataset[dataset[:, column] >= value]
    return left, right

def best_split(data):
    '''Finds the best split for the dataset.'''
    best_gini = 1
    best_column = None
    best_value = None
    best_left = None
    best_right = None

    n_features = data.shape[1] - 1  # Exclude label column
    for column in range(n_features):
        # Sort data and labels according to the feature column
        data_sorted = data[data[:, column].argsort()] # !!!!! Sort data by column to find best split efficiently
        feature_values = data_sorted[:, column]
        labels = data_sorted[:, -1]

        # ! another way to improve perfomance, only consider split points where the class label changes
        for i in range(1, len(feature_values)):
            if labels[i] != labels[i - 1]:
                value = (feature_values[i] + feature_values[i - 1]) / 2
                left, right = split(data, column, value)
                gini = gini_split(left, right)
                if gini < best_gini:
                    best_gini = gini
                    best_column = column
                    best_value = value
                    best_left = left
                    best_right = right

    # Check if a valid split was found
    if best_left is None or best_right is None:
        return None, None, None, None, None

    return best_left, best_right, best_column, best_value, best_gini

def majority_class(data):
    '''Finds the majority class in the data.'''
    labels = data[:, -1].astype(int)
    return np.bincount(labels).argmax()

def build_tree(data, max_depth, depth=0):
    '''Recursively builds the decision tree.'''
    left, right, best_column, best_value, gini = best_split(data)

    # Check if a split was possible or if maximum depth is reached
    if (best_column is None or depth == max_depth or
        left is None or right is None or
        left.size == 0 or right.size == 0):
        return majority_class(data)

    subtree = {
        'feature': best_column,
        'value': best_value,
        'left': build_tree(left, max_depth, depth + 1),
        'right': build_tree(right, max_depth, depth + 1)
    }
    return subtree

# Build the tree with the corrected functions

# %%
tree=build_tree(train_data_pca, 10)
tree
# Out:
# {'feature': 2,
#  'value': 366.4975298185517,
#  'left': {'feature': 1,
#   'value': -41.02902304704946,
#   'left': {'feature': 0,
#    'value': -1142.2567507467038,
#    'left': {'feature': 1,
#     'value': -904.892252026264,
#     'left': {'feature': 7,
#      'value': 42.75650389677854,
#      'left': {'feature': 0,
#       'value': -1480.989879497356,
#       'left': {'feature': 3,
#        'value': 66.77262487101096,
#        'left': {'feature': 7,
#         'value': -184.82784566655846,
#         'left': {'feature': 0,
#          'value': -1508.0340642784772,
#          'left': 0,
#          'right': 2},
#         'right': {'feature': 4,
#          'value': -108.60286227486341,
#          'left': {'feature': 10,
#           'value': 69.78769969247205,
#           'left': 2,
#           'right': 0},
#          'right': {'feature': 14,
#           'value': 17.970959127987467,
#           'left': 4,
#           'right': 3}}},
#        'right': {'feature': 2,
#         'value': 109.64427643029492,
#         'left': {'feature': 1,
#          'value': -1247.4636110284882,
#          'left': 2,
#          'right': 4},
#         'right': {'feature': 0,
#          'value': -1839.2576938160355,
#          'left': 3,
#          'right': {'feature': 12,
#           'value': 144.36532429945333,
#           'left': 0,
#           'right': 3}}}},
#       'right': {'feature': 8,
#        'value': -197.7241315708403,
#        'left': {'feature': 3,
#         'value': 45.28768142185961,
#         'left': {'feature': 5,
#          'value': -94.73788185558365,
#          'left': 4,
#          'right': 0},
#         'right': 4},
#        'right': {'feature': 11,
#         'value': 120.81716839631673,
#         'left': {'feature': 3,
#          'value': -135.07741071266454,
#          'left': {'feature': 5,
#           'value': 60.07089539550323,
#           'left': 4,
#           'right': 2},
#          'right': {'feature': 9,
#           'value': -180.31635126039453,
#           'left': 1,
#           'right': 2}},
#         'right': {'feature': 2,
#          'value': 266.1237983538175,
#          'left': 4,
#          'right': 0}}}},
#      'right': {'feature': 8,
#       'value': 110.90252050012197,
#       'left': {'feature': 1,
#        'value': -1120.6393119846182,
#        'left': {'feature': 3,
#         'value': 93.55160311660809,
#         'left': {'feature': 2,
#          'value': 33.44856912689602,
#          'left': {'feature': 0,
#           'value': -1282.6845769444071,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 12,
#           'value': -115.06079089059814,
#           'left': 2,
#           'right': 4}},
#         'right': {'feature': 0,
#          'value': -1448.6168577590556,
#          'left': 0,
#          'right': 4}},
#        'right': {'feature': 3,
#         'value': -20.24761284087542,
#         'left': 3,
#         'right': {'feature': 0,
#          'value': -1459.8190880693776,
#          'left': 0,
#          'right': 4}}},
#       'right': {'feature': 0,
#        'value': -1183.2668253318088,
#        'left': 2,
#        'right': 4}}},
#     'right': {'feature': 3,
#      'value': -4.303355899911121,
#      'left': {'feature': 2,
#       'value': -80.70611299003346,
#       'left': {'feature': 12,
#        'value': 32.55113041726587,
#        'left': 3,
#        'right': {'feature': 0,
#         'value': -1336.6596265607836,
#         'left': {'feature': 2,
#          'value': -111.53538692244564,
#          'left': 1,
#          'right': {'feature': 0,
#           'value': -1568.932299837991,
#           'left': 1,
#           'right': 3}},
#         'right': 2}},
#       'right': {'feature': 1,
#        'value': -741.2470803734338,
#        'left': {'feature': 0,
#         'value': -1624.4465676570303,
#         'left': {'feature': 0,
#          'value': -1844.3117465883815,
#          'left': 1,
#          'right': 3},
#         'right': {'feature': 9,
#          'value': -76.13781574537367,
#          'left': 0,
#          'right': {'feature': 7,
#           'value': -92.00558502441223,
#           'left': 3,
#           'right': 4}}},
#        'right': {'feature': 7,
#         'value': -422.46063123874364,
#         'left': {'feature': 0,
#          'value': -1277.9880501837833,
#          'left': 1,
#          'right': 4},
#         'right': {'feature': 0,
#          'value': -1190.669966789889,
#          'left': {'feature': 7,
#           'value': -347.8788866027166,
#           'left': 0,
#           'right': 3},
#          'right': {'feature': 12,
#           'value': -23.830487397599356,
#           'left': 3,
#           'right': 0}}}}},
#      'right': {'feature': 1,
#       'value': -603.0301236123526,
#       'left': {'feature': 0,
#        'value': -1725.4806752382983,
#        'left': {'feature': 3,
#         'value': 112.9161678946722,
#         'left': 4,
#         'right': 1},
#        'right': {'feature': 1,
#         'value': -667.2808181278223,
#         'left': {'feature': 4,
#          'value': 53.68132307967233,
#          'left': {'feature': 1,
#           'value': -878.531714412625,
#           'left': 3,
#           'right': 0},
#          'right': {'feature': 0,
#           'value': -1286.2887070263246,
#           'left': 2,
#           'right': 4}},
#         'right': 3}},
#       'right': {'feature': 15,
#        'value': -168.2239812996413,
#        'left': {'feature': 3,
#         'value': 97.74696462984684,
#         'left': 0,
#         'right': {'feature': 0,
#          'value': -1321.3249929088713,
#          'left': 1,
#          'right': 3}},
#        'right': {'feature': 13,
#         'value': 198.8721855284588,
#         'left': 1,
#         'right': 3}}}}},
#    'right': {'feature': 7,
#     'value': 222.22383743221806,
#     'left': {'feature': 2,
#      'value': -24.82318364747573,
#      'left': {'feature': 5,
#       'value': 84.89829943726964,
#       'left': {'feature': 8,
#        'value': 50.53131084544694,
#        'left': {'feature': 7,
#         'value': 108.67845905423803,
#         'left': {'feature': 8,
#          'value': -341.90922207144206,
#          'left': {'feature': 11,
#           'value': 85.1464596767722,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 11,
#           'value': -174.82065057917708,
#           'left': 2,
#           'right': 2}},
#         'right': {'feature': 1,
#          'value': -719.4603552628346,
#          'left': {'feature': 9,
#           'value': -116.21920108674274,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 0,
#           'value': 188.49370967728942,
#           'left': 3,
#           'right': 2}}},
#        'right': {'feature': 3,
#         'value': -321.1928058083247,
#         'left': {'feature': 4,
#          'value': -335.2163235806868,
#          'left': {'feature': 3,
#           'value': -325.97509780637154,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 11,
#           'value': 79.79303249035898,
#           'left': 4,
#           'right': 2}},
#         'right': {'feature': 9,
#          'value': -6.209584972668388,
#          'left': {'feature': 1,
#           'value': -1183.430456546993,
#           'left': 2,
#           'right': 2},
#          'right': {'feature': 3,
#           'value': 17.810343348908876,
#           'left': 2,
#           'right': 2}}}},
#       'right': {'feature': 8,
#        'value': -75.13116600413399,
#        'left': {'feature': 6,
#         'value': -78.85409873012398,
#         'left': {'feature': 4,
#          'value': 212.02124058660536,
#          'left': 4,
#          'right': {'feature': 7,
#           'value': -659.5986562781807,
#           'left': 4,
#           'right': 2}},
#         'right': {'feature': 14,
#          'value': -305.8413340038071,
#          'left': {'feature': 3,
#           'value': 463.05043507268874,
#           'left': 0,
#           'right': 1},
#          'right': {'feature': 1,
#           'value': -489.4238741217649,
#           'left': 4,
#           'right': 2}}},
#        'right': {'feature': 12,
#         'value': 0.9516788450147402,
#         'left': {'feature': 14,
#          'value': 159.44564295042989,
#          'left': {'feature': 10,
#           'value': 211.7406410934957,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 3,
#           'value': 297.7671868334363,
#           'left': 4,
#           'right': 2}},
#         'right': {'feature': 4,
#          'value': -430.01305558004424,
#          'left': {'feature': 2,
#           'value': -557.6728387275892,
#           'left': 2,
#           'right': 1},
#          'right': {'feature': 3,
#           'value': 82.22992082639236,
#           'left': 4,
#           'right': 2}}}}},
#      'right': {'feature': 1,
#       'value': -796.8015716228726,
#       'left': {'feature': 12,
#        'value': -62.09552169437193,
#        'left': {'feature': 3,
#         'value': -177.06135944528745,
#         'left': {'feature': 2,
#          'value': 127.69547250393981,
#          'left': {'feature': 0,
#           'value': -458.3708589619082,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 10,
#           'value': 102.35163634863218,
#           'left': 4,
#           'right': 3}},
#         'right': {'feature': 8,
#          'value': -450.97883624257327,
#          'left': {'feature': 12,
#           'value': -90.3898592344289,
#           'left': 4,
#           'right': 0},
#          'right': {'feature': 2,
#           'value': 345.1138515282232,
#           'left': 2,
#           'right': 0}}},
#        'right': {'feature': 7,
#         'value': 107.44031808045733,
#         'left': {'feature': 4,
#          'value': -356.4228101797521,
#          'left': {'feature': 3,
#           'value': 55.459154421308625,
#           'left': 2,
#           'right': 1},
#          'right': {'feature': 11,
#           'value': 250.23139464602394,
#           'left': 2,
#           'right': 4}},
#         'right': {'feature': 11,
#          'value': 33.68967281867964,
#          'left': {'feature': 8,
#           'value': 122.58151266804137,
#           'left': 4,
#           'right': 2},
#          'right': {'feature': 8,
#           'value': 52.21244863830161,
#           'left': 4,
#           'right': 2}}}},
#       'right': {'feature': 4,
#        'value': 343.72275957489205,
#        'left': {'feature': 3,
#         'value': 19.992462491308103,
#         'left': {'feature': 9,
#          'value': 240.10229587033115,
#          'left': {'feature': 2,
#           'value': 107.62768215749936,
#           'left': 2,
#           'right': 3},
#          'right': {'feature': 4,
#           'value': -568.9506397906567,
#           'left': 1,
#           'right': 3}},
#         'right': {'feature': 4,
#          'value': -671.2016874524458,
#          'left': 1,
#          'right': {'feature': 0,
#           'value': -717.7398717042255,
#           'left': 0,
#           'right': 4}}},
#        'right': {'feature': 3,
#         'value': 455.7608375810403,
#         'left': {'feature': 8,
#          'value': 200.5367100902131,
#          'left': {'feature': 15,
#           'value': -352.56656401864484,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 1,
#           'value': -288.92751851062496,
#           'left': 2,
#           'right': 0}},
#         'right': {'feature': 11,
#          'value': 141.18239503223833,
#          'left': {'feature': 9,
#           'value': 79.87570394869766,
#           'left': 0,
#           'right': 2},
#          'right': {'feature': 14,
#           'value': -158.97062339028372,
#           'left': 0,
#           'right': 4}}}}}},
#     'right': {'feature': 8,
#      'value': 120.69737919563738,
#      'left': {'feature': 12,
#       'value': -230.43574895044296,
#       'left': {'feature': 0,
#        'value': -308.4932169124753,
#        'left': 4,
#        'right': 2},
#       'right': {'feature': 3,
#        'value': 227.52467504596973,
#        'left': {'feature': 1,
#         'value': -656.3227521590081,
#         'left': {'feature': 11,
#          'value': 222.5283396035088,
#          'left': {'feature': 9,
#           'value': -284.88076129402975,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 1,
#           'value': -783.6075033732998,
#           'left': 2,
#           'right': 3}},
#         'right': {'feature': 7,
#          'value': 409.9761302949349,
#          'left': {'feature': 8,
#           'value': 12.71563981265139,
#           'left': 4,
#           'right': 2},
#          'right': {'feature': 5,
#           'value': 319.59657177031846,
#           'left': 4,
#           'right': 2}}},
#        'right': {'feature': 12,
#         'value': 29.300654496481457,
#         'left': 2,
#         'right': {'feature': 2,
#          'value': 241.91148060259604,
#          'left': {'feature': 15,
#           'value': 53.48767144601128,
#           'left': 4,
#           'right': 2},
#          'right': {'feature': 4,
#           'value': 644.1423804182103,
#           'left': 0,
#           'right': 2}}}}},
#      'right': {'feature': 8,
#       'value': 213.02470170688736,
#       'left': {'feature': 12,
#        'value': 44.669400089894125,
#        'left': {'feature': 5,
#         'value': 33.35039874045115,
#         'left': {'feature': 0,
#          'value': 1207.2082547945597,
#          'left': {'feature': 3,
#           'value': -49.34789320157602,
#           'left': 4,
#           'right': 2},
#          'right': 2},
#         'right': {'feature': 14,
#          'value': 178.5604702296439,
#          'left': 2,
#          'right': {'feature': 2,
#           'value': -355.1362175727821,
#           'left': 4,
#           'right': 2}}},
#        'right': {'feature': 14,
#         'value': 135.20067269636252,
#         'left': {'feature': 2,
#          'value': 329.4799494290905,
#          'left': {'feature': 12,
#           'value': 406.05788082454103,
#           'left': 4,
#           'right': 3},
#          'right': {'feature': 0,
#           'value': 1079.4579678862685,
#           'left': 0,
#           'right': 3}},
#         'right': {'feature': 3,
#          'value': -218.23477938902874,
#          'left': 4,
#          'right': {'feature': 4,
#           'value': 153.01284063396005,
#           'left': 0,
#           'right': 2}}}},
#       'right': {'feature': 7,
#        'value': 279.482563452784,
#        'left': {'feature': 10,
#         'value': -52.61977762724685,
#         'left': {'feature': 6,
#          'value': 213.80071714817907,
#          'left': {'feature': 5,
#           'value': -113.64834802764801,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 1,
#           'value': -323.198598019973,
#           'left': 2,
#           'right': 3}},
#         'right': {'feature': 2,
#          'value': 52.51886219715968,
#          'left': {'feature': 1,
#           'value': -140.130510172463,
#           'left': 2,
#           'right': 3},
#          'right': {'feature': 5,
#           'value': 92.23027186572884,
#           'left': 4,
#           'right': 1}}},
#        'right': {'feature': 9,
#         'value': -261.26191920049143,
#         'left': 4,
#         'right': {'feature': 12,
#          'value': 392.99237766431224,
#          'left': {'feature': 10,
#           'value': -146.91216130668903,
#           'left': 2,
#           'right': 2},
#          'right': 4}}}}}}},
#   'right': {'feature': 3,
#    'value': 12.093691914506387,
#    'left': {'feature': 0,
#     'value': 879.1361274026065,
#     'left': {'feature': 3,
#      'value': -82.92413901534832,
#      'left': {'feature': 5,
#       'value': 256.4363745663492,
#       'left': {'feature': 4,
#        'value': -482.57498268255324,
#        'left': {'feature': 2,
#         'value': -132.73557013302485,
#         'left': 2,
#         'right': {'feature': 1,
#          'value': 375.61115757168307,
#          'left': {'feature': 3,
#           'value': -471.6833004837267,
#           'left': 2,
#           'right': 0},
#          'right': {'feature': 11,
#           'value': -81.82145537534936,
#           'left': 4,
#           'right': 3}}},
#        'right': {'feature': 7,
#         'value': -759.354931301745,
#         'left': {'feature': 1,
#          'value': 1139.0079803608726,
#          'left': 0,
#          'right': 4},
#         'right': {'feature': 6,
#          'value': -394.24113052099005,
#          'left': {'feature': 11,
#           'value': -11.843342274919202,
#           'left': 0,
#           'right': 3},
#          'right': {'feature': 0,
#           'value': -1335.688772666602,
#           'left': 3,
#           'right': 3}}}},
#       'right': {'feature': 4,
#        'value': 155.86911821756627,
#        'left': {'feature': 8,
#         'value': 324.94951211626733,
#         'left': {'feature': 15,
#          'value': 75.41984726379535,
#          'left': {'feature': 4,
#           'value': 35.963426014555694,
#           'left': 0,
#           'right': 0},
#          'right': {'feature': 14,
#           'value': -13.02053476772457,
#           'left': 1,
#           'right': 0}},
#         'right': {'feature': 13,
#          'value': -159.5849395458788,
#          'left': 4,
#          'right': {'feature': 3,
#           'value': -163.2252078409022,
#           'left': 3,
#           'right': 0}}},
#        'right': {'feature': 6,
#         'value': -188.20754220251644,
#         'left': {'feature': 4,
#          'value': 431.8925606116384,
#          'left': {'feature': 10,
#           'value': -211.02202555546876,
#           'left': 0,
#           'right': 3},
#          'right': {'feature': 1,
#           'value': 310.97184900730963,
#           'left': 1,
#           'right': 3}},
#         'right': 3}}},
#      'right': {'feature': 8,
#       'value': 182.81579716565528,
#       'left': {'feature': 2,
#        'value': -185.2095870596031,
#        'left': {'feature': 9,
#         'value': 404.07723133911304,
#         'left': 1,
#         'right': {'feature': 0,
#          'value': 255.64075902943273,
#          'left': 3,
#          'right': 0}},
#        'right': {'feature': 5,
#         'value': 9.000223878896911,
#         'left': {'feature': 8,
#          'value': -170.03022311881188,
#          'left': {'feature': 14,
#           'value': -25.877602980876937,
#           'left': 4,
#           'right': 0},
#          'right': 3},
#         'right': {'feature': 2,
#          'value': 261.7640242573214,
#          'left': 1,
#          'right': {'feature': 3,
#           'value': -59.906438294653746,
#           'left': 0,
#           'right': 1}}}},
#       'right': {'feature': 4,
#        'value': -17.06150435033836,
#        'left': {'feature': 7,
#         'value': -100.3350533673771,
#         'left': 0,
#         'right': {'feature': 0,
#          'value': -223.92372007951553,
#          'left': 4,
#          'right': 3}},
#        'right': {'feature': 0,
#         'value': 667.0910838518587,
#         'left': 3,
#         'right': 4}}}},
#     'right': {'feature': 2,
#      'value': -237.3878088679882,
#      'left': {'feature': 4,
#       'value': -397.10295061299564,
#       'left': {'feature': 8,
#        'value': -313.17576113297685,
#        'left': {'feature': 0,
#         'value': 1048.0646018933348,
#         'left': 4,
#         'right': 2},
#        'right': {'feature': 11,
#         'value': -307.00934158920694,
#         'left': 4,
#         'right': {'feature': 15,
#          'value': -322.02124639431077,
#          'left': 4,
#          'right': {'feature': 13,
#           'value': -147.30242142469794,
#           'left': 2,
#           'right': 2}}}},
#       'right': {'feature': 8,
#        'value': 264.5726707071434,
#        'left': {'feature': 10,
#         'value': -242.58986594974837,
#         'left': {'feature': 7,
#          'value': 499.84119565143567,
#          'left': 2,
#          'right': 4},
#         'right': {'feature': 15,
#          'value': -102.1489729239403,
#          'left': {'feature': 0,
#           'value': 1278.3557108772304,
#           'left': 3,
#           'right': 4},
#          'right': {'feature': 3,
#           'value': -500.3925605719875,
#           'left': 2,
#           'right': 4}}},
#        'right': {'feature': 1,
#         'value': 220.5716139697647,
#         'left': 2,
#         'right': 4}}},
#      'right': {'feature': 5,
#       'value': 193.6739166408583,
#       'left': {'feature': 0,
#        'value': 1557.7814705718667,
#        'left': {'feature': 7,
#         'value': 331.77671725049873,
#         'left': {'feature': 13,
#          'value': 145.5792714635582,
#          'left': {'feature': 1,
#           'value': 598.824842131854,
#           'left': 2,
#           'right': 3},
#          'right': {'feature': 3,
#           'value': -11.599539473697256,
#           'left': 3,
#           'right': 0}},
#         'right': {'feature': 8,
#          'value': -79.14408065981684,
#          'left': {'feature': 2,
#           'value': 67.36891528165756,
#           'left': 4,
#           'right': 0},
#          'right': {'feature': 1,
#           'value': 348.0999736826408,
#           'left': 2,
#           'right': 3}}},
#        'right': {'feature': 3,
#         'value': -291.53421431459776,
#         'left': 2,
#         'right': {'feature': 9,
#          'value': 19.70059748136819,
#          'left': 0,
#          'right': 4}}},
#       'right': {'feature': 8,
#        'value': -692.7301184023689,
#        'left': 0,
#        'right': {'feature': 13,
#         'value': -161.76368413747272,
#         'left': {'feature': 0,
#          'value': 1362.2786233793458,
#          'left': 3,
#          'right': 2},
#         'right': {'feature': 4,
#          'value': -818.556418763689,
#          'left': 1,
#          'right': {'feature': 13,
#           'value': 122.44580716860634,
#           'left': 4,
#           'right': 4}}}}}}},
#    'right': {'feature': 0,
#     'value': 216.57620622954914,
#     'left': {'feature': 8,
#      'value': 242.84322992449506,
#      'left': {'feature': 7,
#       'value': -502.59841590048944,
#       'left': {'feature': 11,
#        'value': -73.00948749914564,
#        'left': 4,
#        'right': {'feature': 0,
#         'value': -111.0849688844944,
#         'left': 0,
#         'right': 3}},
#       'right': {'feature': 5,
#        'value': -485.1821355274164,
#        'left': {'feature': 2,
#         'value': 177.70064766161815,
#         'left': {'feature': 0,
#          'value': -51.990924640109824,
#          'left': 0,
#          'right': 3},
#         'right': 4},
#        'right': {'feature': 2,
#         'value': 51.34555033673797,
#         'left': {'feature': 15,
#          'value': -467.29981240296286,
#          'left': 3,
#          'right': {'feature': 14,
#           'value': -563.8407183206725,
#           'left': 1,
#           'right': 1}},
#         'right': {'feature': 4,
#          'value': -211.644676088359,
#          'left': 1,
#          'right': {'feature': 4,
#           'value': -11.556993380352196,
#           'left': 3,
#           'right': 0}}}}},
#      'right': {'feature': 4,
#       'value': -263.22028822972334,
#       'left': {'feature': 0,
#        'value': -520.7817211925982,
#        'left': 1,
#        'right': 0},
#       'right': 3}},
#     'right': {'feature': 0,
#      'value': 1759.3016427695427,
#      'left': {'feature': 4,
#       'value': -543.7515992477549,
#       'left': {'feature': 7,
#        'value': 34.542861547196765,
#        'left': 1,
#        'right': 3},
#       'right': {'feature': 10,
#        'value': 22.312082407696906,
#        'left': {'feature': 1,
#         'value': 959.6873846618969,
#         'left': {'feature': 5,
#          'value': -647.2761070933896,
#          'left': {'feature': 2,
#           'value': 164.201232480116,
#           'left': 4,
#           'right': 0},
#          'right': 4},
#         'right': 0},
#        'right': {'feature': 10,
#         'value': 72.70977644639089,
#         'left': 0,
#         'right': {'feature': 1,
#          'value': 323.748728093967,
#          'left': {'feature': 2,
#           'value': -261.53125670304223,
#           'left': 2,
#           'right': 4},
#          'right': {'feature': 3,
#           'value': 59.79627101099838,
#           'left': 3,
#           'right': 0}}}}},
#      'right': {'feature': 6,
#       'value': -13.983789958029035,
#       'left': {'feature': 7,
#        'value': 352.35535736114355,
#        'left': {'feature': 15,
#         'value': -332.0963602441023,
#         'left': 4,
#         'right': 2},
#        'right': {'feature': 0,
#         'value': 2249.8086847061113,
#         'left': {'feature': 3,
#          'value': 223.51221761012943,
#          'left': 4,
#          'right': 2},
#         'right': 2}},
#       'right': {'feature': 3,
#        'value': 730.2342666159865,
#        'left': 4,
#        'right': 2}}}}}},
#  'right': {'feature': 3,
#   'value': 109.0735973194816,
#   'left': {'feature': 4,
#    'value': 101.77345164060549,
#    'left': {'feature': 2,
#     'value': 665.064436868372,
#     'left': {'feature': 5,
#      'value': -128.97375640719054,
#      'left': {'feature': 1,
#       'value': 322.7315381766275,
#       'left': {'feature': 9,
#        'value': 177.0074443921042,
#        'left': {'feature': 10,
#         'value': -186.91075580279616,
#         'left': {'feature': 3,
#          'value': 42.70307677700852,
#          'left': {'feature': 2,
#           'value': 585.7323781518006,
#           'left': 0,
#           'right': 0},
#          'right': {'feature': 0,
#           'value': -403.78318307206973,
#           'left': 0,
#           'right': 4}},
#         'right': {'feature': 9,
#          'value': -219.02150684811704,
#          'left': {'feature': 4,
#           'value': -39.693765453684975,
#           'left': 0,
#           'right': 4},
#          'right': {'feature': 13,
#           'value': 276.0405180469314,
#           'left': 4,
#           'right': 0}}},
#        'right': {'feature': 5,
#         'value': -232.9480189275901,
#         'left': 4,
#         'right': 3}},
#       'right': {'feature': 11,
#        'value': -235.3372655881309,
#        'left': {'feature': 5,
#         'value': -327.1864075061355,
#         'left': {'feature': 15,
#          'value': -6.479135759139815,
#          'left': 4,
#          'right': {'feature': 0,
#           'value': 170.6870354515272,
#           'left': 4,
#           'right': 0}},
#         'right': 4},
#        'right': {'feature': 10,
#         'value': 98.42086905167452,
#         'left': {'feature': 4,
#          'value': -200.85714398567467,
#          'left': {'feature': 1,
#           'value': 519.3205947560682,
#           'left': 0,
#           'right': 4},
#          'right': {'feature': 2,
#           'value': 657.646348992564,
#           'left': 0,
#           'right': 4}},
#         'right': {'feature': 0,
#          'value': 397.55072460360816,
#          'left': 3,
#          'right': 4}}}},
#      'right': {'feature': 6,
#       'value': -129.8770582412402,
#       'left': {'feature': 8,
#        'value': 278.1578646790923,
#        'left': {'feature': 10,
#         'value': -36.522615078474374,
#         'left': {'feature': 4,
#          'value': -157.82376364572426,
#          'left': {'feature': 12,
#           'value': 89.15144256689594,
#           'left': 0,
#           'right': 4},
#          'right': {'feature': 2,
#           'value': 658.0832591497096,
#           'left': 0,
#           'right': 4}},
#         'right': {'feature': 5,
#          'value': 192.00036253346502,
#          'left': {'feature': 3,
#           'value': -40.493491144022265,
#           'left': 3,
#           'right': 0},
#          'right': {'feature': 11,
#           'value': -256.21617823769463,
#           'left': 4,
#           'right': 0}}},
#        'right': {'feature': 11,
#         'value': -66.60392796474908,
#         'left': {'feature': 0,
#          'value': 354.7882598722149,
#          'left': 0,
#          'right': {'feature': 0,
#           'value': 377.9537625775599,
#           'left': 4,
#           'right': 3}},
#         'right': 3}},
#       'right': {'feature': 5,
#        'value': 438.8382227774891,
#        'left': {'feature': 13,
#         'value': -215.7504538648698,
#         'left': 4,
#         'right': {'feature': 10,
#          'value': -171.80849822370777,
#          'left': {'feature': 7,
#           'value': -102.96774572496645,
#           'left': 2,
#           'right': 0},
#          'right': {'feature': 8,
#           'value': 339.1414109203214,
#           'left': 4,
#           'right': 0}}},
#        'right': {'feature': 0,
#         'value': -555.2265342426002,
#         'left': 3,
#         'right': {'feature': 7,
#          'value': -166.02240233027848,
#          'left': {'feature': 4,
#           'value': 1.2555699284173159,
#           'left': 0,
#           'right': 3},
#          'right': 1}}}}},
#     'right': {'feature': 4,
#      'value': 1.6915803106956702,
#      'left': {'feature': 1,
#       'value': 674.2246717349365,
#       'left': {'feature': 12,
#        'value': 52.62323653906152,
#        'left': {'feature': 7,
#         'value': 5.7640893349739315,
#         'left': {'feature': 15,
#          'value': 114.52968377793201,
#          'left': {'feature': 8,
#           'value': 271.48029749192784,
#           'left': 4,
#           'right': 0},
#          'right': {'feature': 0,
#           'value': -646.813682640975,
#           'left': 3,
#           'right': 0}},
#         'right': {'feature': 1,
#          'value': -702.4846629468992,
#          'left': {'feature': 2,
#           'value': 712.4339310331545,
#           'left': 0,
#           'right': 4},
#          'right': {'feature': 5,
#           'value': 171.04139166743192,
#           'left': 0,
#           'right': 3}}},
#        'right': {'feature': 10,
#         'value': 169.5502204692522,
#         'left': {'feature': 3,
#          'value': -663.202870068764,
#          'left': 0,
#          'right': {'feature': 8,
#           'value': -287.0077190127197,
#           'left': 4,
#           'right': 4}},
#         'right': 0}},
#       'right': {'feature': 9,
#        'value': 8.263907888391806,
#        'left': {'feature': 3,
#         'value': -94.75635363065685,
#         'left': {'feature': 3,
#          'value': -147.7729449876755,
#          'left': 0,
#          'right': 4},
#         'right': 0},
#        'right': {'feature': 9,
#         'value': 66.26732305460956,
#         'left': 4,
#         'right': {'feature': 0,
#          'value': 743.7257345875435,
#          'left': 3,
#          'right': {'feature': 6,
#           'value': 149.20390885491162,
#           'left': 4,
#           'right': 0}}}}},
#      'right': {'feature': 8,
#       'value': 422.27219843835053,
#       'left': {'feature': 9,
#        'value': 170.17372613177653,
#        'left': {'feature': 5,
#         'value': 553.5457519559495,
#         'left': 0,
#         'right': {'feature': 0,
#          'value': -18.285808449243405,
#          'left': 4,
#          'right': 0}},
#        'right': 4},
#       'right': 4}}},
#    'right': {'feature': 8,
#     'value': -10.273768039863,
#     'left': {'feature': 6,
#      'value': 67.46093574869532,
#      'left': {'feature': 11,
#       'value': 208.47860961041718,
#       'left': {'feature': 14,
#        'value': 12.159624173636324,
#        'left': {'feature': 10,
#         'value': -118.84374273124732,
#         'left': 4,
#         'right': {'feature': 0,
#          'value': -1116.411237650239,
#          'left': 3,
#          'right': 0}},
#        'right': {'feature': 14,
#         'value': 343.94379831980643,
#         'left': {'feature': 8,
#          'value': -712.8627108288217,
#          'left': 4,
#          'right': {'feature': 14,
#           'value': 220.8001437509781,
#           'left': 0,
#           'right': 0}},
#         'right': {'feature': 0,
#          'value': -32.3032993877564,
#          'left': 0,
#          'right': 4}}},
#       'right': {'feature': 1,
#        'value': 896.1900156317647,
#        'left': 3,
#        'right': 0}},
#      'right': {'feature': 10,
#       'value': -135.00271529510763,
#       'left': {'feature': 13,
#        'value': -95.68817652664471,
#        'left': {'feature': 15,
#         'value': -271.79220918645,
#         'left': 0,
#         'right': 4},
#        'right': 0},
#       'right': {'feature': 4,
#        'value': 491.0800826188618,
#        'left': {'feature': 0,
#         'value': -1170.6603879323957,
#         'left': 2,
#         'right': {'feature': 14,
#          'value': -235.6375071863144,
#          'left': 0,
#          'right': 4}},
#        'right': 2}}},
#     'right': {'feature': 3,
#      'value': -75.81408615555657,
#      'left': {'feature': 7,
#       'value': 249.1182170695966,
#       'left': {'feature': 8,
#        'value': 160.49165430314758,
#        'left': {'feature': 13,
#         'value': 113.92135045217177,
#         'left': {'feature': 2,
#          'value': 519.2408806836839,
#          'left': 3,
#          'right': {'feature': 2,
#           'value': 540.1828327655882,
#           'left': 0,
#           'right': 3}},
#         'right': {'feature': 12,
#          'value': -57.284577925445774,
#          'left': {'feature': 0,
#           'value': -787.3715819489565,
#           'left': 4,
#           'right': 3},
#          'right': {'feature': 14,
#           'value': -105.09755773241596,
#           'left': 1,
#           'right': 0}}},
#        'right': {'feature': 6,
#         'value': -469.99721222510345,
#         'left': {'feature': 0,
#          'value': -523.1122719814998,
#          'left': 0,
#          'right': 3},
#         'right': 3}},
#       'right': {'feature': 2,
#        'value': 713.5215694491089,
#        'left': {'feature': 3,
#         'value': -488.6717123017802,
#         'left': 4,
#         'right': 2},
#        'right': 0}},
#      'right': {'feature': 2,
#       'value': 437.36176530722696,
#       'left': {'feature': 0,
#        'value': -454.68942228167316,
#        'left': 3,
#        'right': {'feature': 0,
#         'value': 478.8466565346673,
#         'left': 2,
#         'right': 4}},
#       'right': 0}}}},
#   'right': {'feature': 5,
#    'value': 129.17570122755822,
#    'left': {'feature': 11,
#     'value': 226.85996688168768,
#     'left': {'feature': 3,
#      'value': 214.65829842383113,
#      'left': {'feature': 8,
#       'value': -353.0737727016863,
#       'left': {'feature': 0,
#        'value': 1015.0694511353088,
#        'left': {'feature': 14,
#         'value': -194.2811588926522,
#         'left': {'feature': 2,
#          'value': 674.4514923652366,
#          'left': 0,
#          'right': 4},
#         'right': 4},
#        'right': {'feature': 1,
#         'value': 745.0697659277814,
#         'left': {'feature': 0,
#          'value': 1111.2316311293437,
#          'left': 0,
#          'right': 4},
#         'right': 0}},
#       'right': {'feature': 6,
#        'value': 650.9007076771514,
#        'left': {'feature': 9,
#         'value': 174.23626409145766,
#         'left': {'feature': 2,
#          'value': 633.0194248975689,
#          'left': {'feature': 14,
#           'value': 43.32640676168992,
#           'left': 0,
#           'right': 0},
#          'right': {'feature': 4,
#           'value': -145.6768698004744,
#           'left': 0,
#           'right': 0}},
#         'right': {'feature': 0,
#          'value': 406.7404136151406,
#          'left': {'feature': 5,
#           'value': -16.131417081090333,
#           'left': 0,
#           'right': 4},
#          'right': 4}},
#        'right': 4}},
#      'right': {'feature': 7,
#       'value': -597.6141040704183,
#       'left': 4,
#       'right': {'feature': 12,
#        'value': 252.82069250325287,
#        'left': {'feature': 13,
#         'value': -360.2079956713305,
#         'left': {'feature': 1,
#          'value': 835.5353367182302,
#          'left': 4,
#          'right': 0},
#         'right': {'feature': 1,
#          'value': 1362.1635797953945,
#          'left': {'feature': 13,
#           'value': 281.63718799133903,
#           'left': 0,
#           'right': 4},
#          'right': 3}},
#        'right': {'feature': 0,
#         'value': 371.6089164325401,
#         'left': {'feature': 9,
#          'value': -93.81786084412337,
#          'left': {'feature': 0,
#           'value': -112.38145382390485,
#           'left': 3,
#           'right': 0},
#          'right': 4},
#         'right': 0}}}},
#     'right': {'feature': 8,
#      'value': -64.76549329407872,
#      'left': {'feature': 7,
#       'value': 115.73974557696783,
#       'left': {'feature': 3,
#        'value': 297.1917457684326,
#        'left': {'feature': 4,
#         'value': -236.09336542667805,
#         'left': 0,
#         'right': 4},
#        'right': {'feature': 2,
#         'value': 651.5283762144246,
#         'left': 4,
#         'right': {'feature': 2,
#          'value': 1040.218542381676,
#          'left': 0,
#          'right': 4}}},
#       'right': 0},
#      'right': {'feature': 13,
#       'value': -193.37129896616625,
#       'left': 4,
#       'right': {'feature': 15,
#        'value': 57.238935470107606,
#        'left': {'feature': 12,
#         'value': -232.9915844092193,
#         'left': {'feature': 9,
#          'value': -301.9318898692312,
#          'left': 0,
#          'right': 4},
#         'right': 0},
#        'right': {'feature': 9,
#         'value': -256.71665519228594,
#         'left': 4,
#         'right': {'feature': 0,
#          'value': 322.3962174200028,
#          'left': {'feature': 0,
#           'value': 138.65897139397953,
#           'left': 4,
#           'right': 2},
#          'right': 0}}}}}},
#    'right': {'feature': 11,
#     'value': 211.9048551487159,
#     'left': {'feature': 12,
#      'value': 105.59519386553445,
#      'left': {'feature': 2,
#       'value': 643.3803294662664,
#       'left': {'feature': 11,
#        'value': 128.42335564663978,
#        'left': 2,
#        'right': {'feature': 6,
#         'value': 391.1769114375842,
#         'left': 4,
#         'right': 2}},
#       'right': 0},
#      'right': {'feature': 4,
#       'value': -490.8999861484392,
#       'left': 1,
#       'right': {'feature': 0,
#        'value': 2152.571859306048,
#        'left': {'feature': 8,
#         'value': -362.1587345953816,
#         'left': 3,
#         'right': {'feature': 9,
#          'value': -118.0421035603006,
#          'left': 4,
#          'right': {'feature': 9,
#           'value': 260.1015669939252,
#           'left': 0,
#           'right': 2}}},
#        'right': 2}}},
#     'right': {'feature': 15,
#      'value': -235.58522977403427,
#      'left': {'feature': 2,
#       'value': 650.3702421717217,
#       'left': {'feature': 8,
#        'value': -268.2800705221772,
#        'left': {'feature': 5,
#         'value': 785.381260508293,
#         'left': {'feature': 14,
#          'value': -258.7728411514851,
#          'left': 0,
#          'right': 2},
#         'right': 4},
#        'right': {'feature': 0,
#         'value': 478.9897572916934,
#         'left': 0,
#         'right': 4}},
#       'right': {'feature': 7,
#        'value': -195.25578724052858,
#        'left': 4,
#        'right': 0}},
#      'right': {'feature': 1,
#       'value': -89.01093988106265,
#       'left': {'feature': 11,
#        'value': 374.37966043027507,
#        'left': {'feature': 14,
#         'value': -25.410518283060412,
#         'left': {'feature': 4,
#          'value': 446.27779772872026,
#          'left': 0,
#          'right': 2},
#         'right': {'feature': 2,
#          'value': 462.71400100735843,
#          'left': {'feature': 1,
#           'value': -899.9063114192064,
#           'left': 4,
#           'right': 2},
#          'right': 4}},
#        'right': 4},
#       'right': {'feature': 14,
#        'value': -282.1709622928911,
#        'left': 0,
#        'right': {'feature': 3,
#         'value': 790.6411490432271,
#         'left': 4,
#         'right': 0}}}}}}}}

# %%
def predict(tree, features):
    if not isinstance(tree, dict):
        return tree
    if features[tree['feature']] < tree['value']:
        return predict(tree['left'], features)
    else:
        return predict(tree['right'], features)

# %%
from sklearn.metrics import accuracy_score

# Predict for each feature vector in pca_test
y_pred = [predict(tree, features) for features in pca_test]
accuracy = accuracy_score(test_labels, y_pred)
accuracy
# Out:
# 0.7694
